# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
# Load the data from the file on Google Drive
data_file_path = '/content/drive/MyDrive/data.txt'
data = pd.read_csv(data_file_path, sep='\t', header=None)

# Extract features (x1 and x2) and labels (y1 and y2)
features = data.iloc[:, :2].values
labels = data.iloc[:, 2:].values

# Divide the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(features, labels, test_size=0.2, random_state=42)

# %%
features[4,1]
# Out:
# 0.865894545727409

# %%
labels[10,0]
# Out:
# 0

# %%
# Define the neural network architecture
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(2,)),    # Input layer with two inputs (features x1 and x2)
    tf.keras.layers.Dense(20, activation='relu'),    # First hidden layer with 20 neurons and ReLU activation
    tf.keras.layers.Dense(40, activation='relu'),    # Second hidden layer with 40 neurons and ReLU activation
    tf.keras.layers.Dense(2, activation='softmax')   # Output layer with two outputs (labels y1 and y2) and softmax activation
])

# %%
# Compile the model with SGD optimizer and learning rate of 0.005
learning_rate = 0.005
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the neural network
epochs = 100
batch_size = 32
history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val))

# Evaluate the model on the validation set
val_loss, val_accuracy = model.evaluate(X_val, y_val)
print(f"Validation loss: {val_loss:.4f}, Validation accuracy: {val_accuracy:.4f}")

# %%
# Define the neural network architecture (model1 with tanh activation)
model1 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(2,)),    # Input layer with two inputs (features x1 and x2)
    tf.keras.layers.Dense(40, activation='tanh'),    # First hidden layer with 20 neurons and tanh activation
    tf.keras.layers.Dense(20, activation='tanh'),    # Second hidden layer with 40 neurons and tanh activation
    tf.keras.layers.Dense(2, activation='softmax')   # Output layer with two outputs (labels y1 and y2) and softmax activation
])

# Compile the model1 with SGD optimizer and learning rate of 0.005
learning_rate = 0.005
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
model1.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Train the neural network (model1)
epochs = 100
batch_size = 32
history1 = model1.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val))

# Evaluate the model1 on the validation set
val_loss, val_accuracy = model1.evaluate(X_val, y_val)
print(f"Validation loss: {val_loss:.4f}, Validation accuracy: {val_accuracy:.4f}")
# Out:
# Epoch 1/100
# 1203/1203 [==============================] - 3s 2ms/step - loss: 0.6916 - accuracy: 0.5320 - val_loss: 0.6879 - val_accuracy: 0.5518
# Epoch 2/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6858 - accuracy: 0.5632 - val_loss: 0.6840 - val_accuracy: 0.5693
# Epoch 3/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6819 - accuracy: 0.5696 - val_loss: 0.6805 - val_accuracy: 0.5675
# Epoch 4/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6786 - accuracy: 0.5719 - val_loss: 0.6777 - val_accuracy: 0.5670
# Epoch 5/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6758 - accuracy: 0.5704 - val_loss: 0.6754 - val_accuracy: 0.5653
# Epoch 6/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6736 - accuracy: 0.5712 - val_loss: 0.6738 - val_accuracy: 0.5679
# Epoch 7/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6720 - accuracy: 0.5722 - val_loss: 0.6727 - val_accuracy: 0.5668
# Epoch 8/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6709 - accuracy: 0.5720 - val_loss: 0.6726 - val_accuracy: 0.5685
# Epoch 9/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6703 - accuracy: 0.5717 - val_loss: 0.6717 - val_accuracy: 0.5670
# Epoch 10/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6699 - accuracy: 0.5720 - val_loss: 0.6718 - val_accuracy: 0.5687
# Epoch 11/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6697 - accuracy: 0.5719 - val_loss: 0.6715 - val_accuracy: 0.5670
# Epoch 12/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6696 - accuracy: 0.5726 - val_loss: 0.6715 - val_accuracy: 0.5698
# Epoch 13/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6695 - accuracy: 0.5736 - val_loss: 0.6715 - val_accuracy: 0.5675
# Epoch 14/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6695 - accuracy: 0.5733 - val_loss: 0.6715 - val_accuracy: 0.5700
# Epoch 15/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5728 - val_loss: 0.6715 - val_accuracy: 0.5689
# Epoch 16/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6695 - accuracy: 0.5733 - val_loss: 0.6716 - val_accuracy: 0.5666
# Epoch 17/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6695 - accuracy: 0.5731 - val_loss: 0.6716 - val_accuracy: 0.5675
# Epoch 18/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6695 - accuracy: 0.5717 - val_loss: 0.6716 - val_accuracy: 0.5696
# Epoch 19/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6695 - accuracy: 0.5721 - val_loss: 0.6716 - val_accuracy: 0.5686
# Epoch 20/100
# 1203/1203 [==============================] - 4s 3ms/step - loss: 0.6695 - accuracy: 0.5727 - val_loss: 0.6717 - val_accuracy: 0.5683
# Epoch 21/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5721 - val_loss: 0.6716 - val_accuracy: 0.5675
# Epoch 22/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6695 - accuracy: 0.5727 - val_loss: 0.6716 - val_accuracy: 0.5691
# Epoch 23/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6692 - accuracy: 0.5730 - val_loss: 0.6721 - val_accuracy: 0.5711
# Epoch 24/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5730 - val_loss: 0.6716 - val_accuracy: 0.5676
# Epoch 25/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5719 - val_loss: 0.6716 - val_accuracy: 0.5692
# Epoch 26/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6695 - accuracy: 0.5724 - val_loss: 0.6716 - val_accuracy: 0.5682
# Epoch 27/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5726 - val_loss: 0.6716 - val_accuracy: 0.5665
# Epoch 28/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5722 - val_loss: 0.6716 - val_accuracy: 0.5674
# Epoch 29/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5721 - val_loss: 0.6716 - val_accuracy: 0.5673
# Epoch 30/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5719 - val_loss: 0.6716 - val_accuracy: 0.5686
# Epoch 31/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5727 - val_loss: 0.6716 - val_accuracy: 0.5676
# Epoch 32/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5720 - val_loss: 0.6716 - val_accuracy: 0.5667
# Epoch 33/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5728 - val_loss: 0.6715 - val_accuracy: 0.5685
# Epoch 34/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5735 - val_loss: 0.6715 - val_accuracy: 0.5676
# Epoch 35/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5713 - val_loss: 0.6717 - val_accuracy: 0.5676
# Epoch 36/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5726 - val_loss: 0.6715 - val_accuracy: 0.5686
# Epoch 37/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5712 - val_loss: 0.6716 - val_accuracy: 0.5667
# Epoch 38/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5732 - val_loss: 0.6715 - val_accuracy: 0.5686
# Epoch 39/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5726 - val_loss: 0.6715 - val_accuracy: 0.5686
# Epoch 40/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5726 - val_loss: 0.6716 - val_accuracy: 0.5688
# Epoch 41/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5719 - val_loss: 0.6719 - val_accuracy: 0.5672
# Epoch 42/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5716 - val_loss: 0.6715 - val_accuracy: 0.5694
# Epoch 43/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5725 - val_loss: 0.6715 - val_accuracy: 0.5685
# Epoch 44/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5717 - val_loss: 0.6716 - val_accuracy: 0.5666
# Epoch 45/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6693 - accuracy: 0.5738 - val_loss: 0.6716 - val_accuracy: 0.5664
# Epoch 46/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5721 - val_loss: 0.6716 - val_accuracy: 0.5666
# Epoch 47/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5728 - val_loss: 0.6717 - val_accuracy: 0.5683
# Epoch 48/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5713 - val_loss: 0.6715 - val_accuracy: 0.5677
# Epoch 49/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5711 - val_loss: 0.6716 - val_accuracy: 0.5669
# Epoch 50/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5723 - val_loss: 0.6715 - val_accuracy: 0.5685
# Epoch 51/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5714 - val_loss: 0.6715 - val_accuracy: 0.5685
# Epoch 52/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5722 - val_loss: 0.6715 - val_accuracy: 0.5686
# Epoch 53/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5719 - val_loss: 0.6715 - val_accuracy: 0.5687
# Epoch 54/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5727 - val_loss: 0.6716 - val_accuracy: 0.5665
# Epoch 55/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6693 - accuracy: 0.5735 - val_loss: 0.6716 - val_accuracy: 0.5690
# Epoch 56/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5713 - val_loss: 0.6715 - val_accuracy: 0.5683
# Epoch 57/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5721 - val_loss: 0.6716 - val_accuracy: 0.5692
# Epoch 58/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5728 - val_loss: 0.6716 - val_accuracy: 0.5672
# Epoch 59/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5729 - val_loss: 0.6715 - val_accuracy: 0.5690
# Epoch 60/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5730 - val_loss: 0.6717 - val_accuracy: 0.5687
# Epoch 61/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5724 - val_loss: 0.6716 - val_accuracy: 0.5694
# Epoch 62/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5718 - val_loss: 0.6715 - val_accuracy: 0.5680
# Epoch 63/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5714 - val_loss: 0.6716 - val_accuracy: 0.5674
# Epoch 64/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5727 - val_loss: 0.6715 - val_accuracy: 0.5686
# Epoch 65/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5727 - val_loss: 0.6715 - val_accuracy: 0.5688
# Epoch 66/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5723 - val_loss: 0.6715 - val_accuracy: 0.5682
# Epoch 67/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6693 - accuracy: 0.5720 - val_loss: 0.6719 - val_accuracy: 0.5682
# Epoch 68/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5722 - val_loss: 0.6716 - val_accuracy: 0.5676
# Epoch 69/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5724 - val_loss: 0.6715 - val_accuracy: 0.5685
# Epoch 70/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6693 - accuracy: 0.5719 - val_loss: 0.6718 - val_accuracy: 0.5684
# Epoch 71/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5723 - val_loss: 0.6716 - val_accuracy: 0.5689
# Epoch 72/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5716 - val_loss: 0.6719 - val_accuracy: 0.5676
# Epoch 73/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6693 - accuracy: 0.5741 - val_loss: 0.6716 - val_accuracy: 0.5679
# Epoch 74/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5718 - val_loss: 0.6715 - val_accuracy: 0.5681
# Epoch 75/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6693 - accuracy: 0.5717 - val_loss: 0.6715 - val_accuracy: 0.5689
# Epoch 76/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5727 - val_loss: 0.6716 - val_accuracy: 0.5664
# Epoch 77/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5721 - val_loss: 0.6715 - val_accuracy: 0.5688
# Epoch 78/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5721 - val_loss: 0.6716 - val_accuracy: 0.5667
# Epoch 79/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6693 - accuracy: 0.5722 - val_loss: 0.6715 - val_accuracy: 0.5687
# Epoch 80/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6693 - accuracy: 0.5717 - val_loss: 0.6715 - val_accuracy: 0.5663
# Epoch 81/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6693 - accuracy: 0.5733 - val_loss: 0.6715 - val_accuracy: 0.5669
# Epoch 82/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5719 - val_loss: 0.6715 - val_accuracy: 0.5691
# Epoch 83/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6693 - accuracy: 0.5722 - val_loss: 0.6715 - val_accuracy: 0.5691
# Epoch 84/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6693 - accuracy: 0.5722 - val_loss: 0.6715 - val_accuracy: 0.5670
# Epoch 85/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5706 - val_loss: 0.6715 - val_accuracy: 0.5685
# Epoch 86/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5730 - val_loss: 0.6716 - val_accuracy: 0.5673
# Epoch 87/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5726 - val_loss: 0.6715 - val_accuracy: 0.5669
# Epoch 88/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5719 - val_loss: 0.6717 - val_accuracy: 0.5684
# Epoch 89/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5724 - val_loss: 0.6715 - val_accuracy: 0.5679
# Epoch 90/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5729 - val_loss: 0.6715 - val_accuracy: 0.5687
# Epoch 91/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6692 - accuracy: 0.5738 - val_loss: 0.6715 - val_accuracy: 0.5667
# Epoch 92/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5716 - val_loss: 0.6715 - val_accuracy: 0.5687
# Epoch 93/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6693 - accuracy: 0.5719 - val_loss: 0.6715 - val_accuracy: 0.5686
# Epoch 94/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5720 - val_loss: 0.6715 - val_accuracy: 0.5688
# Epoch 95/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6694 - accuracy: 0.5727 - val_loss: 0.6715 - val_accuracy: 0.5667
# Epoch 96/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6693 - accuracy: 0.5724 - val_loss: 0.6715 - val_accuracy: 0.5683
# Epoch 97/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6693 - accuracy: 0.5725 - val_loss: 0.6716 - val_accuracy: 0.5703
# Epoch 98/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6694 - accuracy: 0.5723 - val_loss: 0.6715 - val_accuracy: 0.5692
# Epoch 99/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6693 - accuracy: 0.5718 - val_loss: 0.6715 - val_accuracy: 0.5685
# Epoch 100/100
# 1203/1203 [==============================] - 2s 1ms/step - loss: 0.6693 - accuracy: 0.5723 - val_loss: 0.6715 - val_accuracy: 0.5670
# 301/301 [==============================] - 0s 1ms/step - loss: 0.6715 - accuracy: 0.5670
# Validation loss: 0.6715, Validation accuracy: 0.5670

# %%
# Define the neural network architecture (model1 with tanh activation)
model1 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(2,)),    # Input layer with two inputs (features x1 and x2)
    tf.keras.layers.Dense(20, activation='tanh'),    # First hidden layer with 20 neurons and tanh activation
    tf.keras.layers.Dense(40, activation='tanh'),    # Second hidden layer with 40 neurons and tanh activation
    tf.keras.layers.Dense(2, activation='sigmoid')   # Output layer with two outputs (labels y1 and y2) and softmax activation
])

# Compile the model1 with SGD optimizer and learning rate of 0.005
learning_rate = 0.005
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
model1.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Train the neural network (model1)
epochs = 100
batch_size = 32
history1 = model1.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val))

# Evaluate the model1 on the validation set
val_loss, val_accuracy = model1.evaluate(X_val, y_val)
print(f"Validation loss: {val_loss:.4f}, Validation accuracy: {val_accuracy:.4f}")
# Out:
# Epoch 1/100
# 1203/1203 [==============================] - 3s 2ms/step - loss: 0.6857 - accuracy: 0.5592 - val_loss: 0.6833 - val_accuracy: 0.5684
# Epoch 2/100
# 1203/1203 [==============================] - 4s 3ms/step - loss: 0.6809 - accuracy: 0.5708 - val_loss: 0.6794 - val_accuracy: 0.5685
# Epoch 3/100
# 1203/1203 [==============================] - 3s 2ms/step - loss: 0.6774 - accuracy: 0.5697 - val_loss: 0.6766 - val_accuracy: 0.5657
# Epoch 4/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6748 - accuracy: 0.5703 - val_loss: 0.6746 - val_accuracy: 0.5671
# Epoch 5/100
# 1203/1203 [==============================] - 3s 2ms/step - loss: 0.6730 - accuracy: 0.5692 - val_loss: 0.6736 - val_accuracy: 0.5687
# Epoch 6/100
# 1203/1203 [==============================] - 3s 2ms/step - loss: 0.6718 - accuracy: 0.5698 - val_loss: 0.6725 - val_accuracy: 0.5650
# Epoch 7/100
# 1203/1203 [==============================] - 3s 3ms/step - loss: 0.6709 - accuracy: 0.5695 - val_loss: 0.6721 - val_accuracy: 0.5692
# Epoch 8/100
# 1203/1203 [==============================] - 3s 3ms/step - loss: 0.6704 - accuracy: 0.5698 - val_loss: 0.6717 - val_accuracy: 0.5675
# Epoch 9/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6701 - accuracy: 0.5704 - val_loss: 0.6716 - val_accuracy: 0.5668
# Epoch 10/100
# 1203/1203 [==============================] - 3s 2ms/step - loss: 0.6699 - accuracy: 0.5716 - val_loss: 0.6715 - val_accuracy: 0.5679
# Epoch 11/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6697 - accuracy: 0.5712 - val_loss: 0.6715 - val_accuracy: 0.5672
# Epoch 12/100
# 1203/1203 [==============================] - 3s 2ms/step - loss: 0.6697 - accuracy: 0.5719 - val_loss: 0.6715 - val_accuracy: 0.5670
# Epoch 13/100
# 1203/1203 [==============================] - 3s 3ms/step - loss: 0.6696 - accuracy: 0.5724 - val_loss: 0.6715 - val_accuracy: 0.5677
# Epoch 14/100
# 1203/1203 [==============================] - 3s 2ms/step - loss: 0.6696 - accuracy: 0.5726 - val_loss: 0.6717 - val_accuracy: 0.5681
# Epoch 15/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6696 - accuracy: 0.5731 - val_loss: 0.6716 - val_accuracy: 0.5666
# Epoch 16/100
# 1203/1203 [==============================] - 3s 2ms/step - loss: 0.6695 - accuracy: 0.5729 - val_loss: 0.6716 - val_accuracy: 0.5680
# Epoch 17/100
# 1203/1203 [==============================] - 3s 2ms/step - loss: 0.6695 - accuracy: 0.5723 - val_loss: 0.6716 - val_accuracy: 0.5682
# Epoch 18/100
# 1203/1203 [==============================] - 4s 3ms/step - loss: 0.6695 - accuracy: 0.5730 - val_loss: 0.6716 - val_accuracy: 0.5667
# Epoch 19/100
# 1203/1203 [==============================] - 3s 2ms/step - loss: 0.6695 - accuracy: 0.5730 - val_loss: 0.6716 - val_accuracy: 0.5670
# Epoch 20/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6695 - accuracy: 0.5715 - val_loss: 0.6716 - val_accuracy: 0.5685
# Epoch 21/100
# 1203/1203 [==============================] - 3s 2ms/step - loss: 0.6695 - accuracy: 0.5723 - val_loss: 0.6717 - val_accuracy: 0.5686
# Epoch 22/100
# 1203/1203 [==============================] - 3s 2ms/step - loss: 0.6695 - accuracy: 0.5733 - val_loss: 0.6717 - val_accuracy: 0.5680
# Epoch 23/100
# 1203/1203 [==============================] - 3s 3ms/step - loss: 0.6695 - accuracy: 0.5729 - val_loss: 0.6716 - val_accuracy: 0.5669
# Epoch 24/100
# 1203/1203 [==============================] - 3s 3ms/step - loss: 0.6695 - accuracy: 0.5726 - val_loss: 0.6716 - val_accuracy: 0.5679
# Epoch 25/100
# 1203/1203 [==============================] - 2s 2ms/step - loss: 0.6695 - accuracy: 0.5716 - val_loss: 0.6717 - val_accuracy: 0.5699
# Epoch 26/100
# 1175/1203 [============================>.] - ETA: 0s - loss: 0.6695 - accuracy: 0.5712
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-1ac396724b41> in <cell line: 17>()
#      15 epochs = 100
#      16 batch_size = 32
# ---> 17 history1 = model1.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val))
#      18
#      19 # Evaluate the model1 on the validation set
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1727                             steps_per_execution=self._steps_per_execution,
#    1728                         )
# -> 1729                     val_logs = self.evaluate(
#    1730                         x=val_x,
#    1731                         y=val_y,
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2065                 self.reset_metrics()
#    2066                 with data_handler.catch_stop_iteration():
# -> 2067                     for step in data_handler.steps():
#    2068                         with tf.profiler.experimental.Trace(
#    2069                             "test", step_num=step, _r=1
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/data_adapter.py in steps(self)
#    1373             if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1374                 break
# -> 1375             original_spe = self._steps_per_execution.numpy().item()
#    1376             can_run_full_execution = (
#    1377                 original_spe == 1
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/resource_variable_ops.py in numpy(self)
#     645   def numpy(self):
#     646     if context.executing_eagerly():
# --> 647       return self.read_value().numpy()
#     648     raise NotImplementedError(
#     649         "numpy() is only available when eager execution is enabled.")
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/resource_variable_ops.py in read_value(self)
#     772     """
#     773     with ops.name_scope("Read"):
# --> 774       value = self._read_variable_op()
#     775     # Return an identity so it can get placed on whatever device the context
#     776     # specifies instead of the device where the variable is.
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/resource_variable_ops.py in _read_variable_op(self, no_copy)
#     751           result = read_and_set_handle(no_copy)
#     752     else:
# --> 753       result = read_and_set_handle(no_copy)
#     754
#     755     if not context.executing_eagerly():
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/resource_variable_ops.py in read_and_set_handle(no_copy)
#     741       if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     742         gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 743       result = gen_resource_variable_ops.read_variable_op(
#     744           self.handle, self._dtype)
#     745       _maybe_set_handle_data(self._dtype, self.handle, result)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_resource_variable_ops.py in read_variable_op(resource, dtype, name)
#     522   if tld.is_eager:
#     523     try:
# --> 524       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     525         _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     526       return _result
#
# KeyboardInterrupt:

# %%
# Define the neural network architecture (model2)
model2 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(2,)),    # Input layer with two inputs (features x1 and x2)
    tf.keras.layers.Dense(50, activation='relu'),    # First hidden layer with 50 neurons and ReLU activation
    tf.keras.layers.Dense(40, activation='relu'),    # Second hidden layer with 40 neurons and ReLU activation
    tf.keras.layers.Dense(30, activation='relu'),    # Third hidden layer with 30 neurons and ReLU activation
    tf.keras.layers.Dense(20, activation='relu'),    # Fourth hidden layer with 20 neurons and ReLU activation
    tf.keras.layers.Dense(10, activation='relu'),    # Fifth hidden layer with 10 neurons and ReLU activation
    tf.keras.layers.Dense(2, activation='softmax')   # Output layer with two outputs (labels y1 and y2) and softmax activation
])

# Compile the model2 with SGD optimizer and learning rate of 0.005
learning_rate = 0.005
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
model2.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Train the neural network (model2)
epochs = 100
batch_size = 32
history = model2.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val))

# Evaluate the model2 on the validation set
val_loss, val_accuracy = model2.evaluate(X_val, y_val)
print(f"Validation loss: {val_loss:.4f}, Validation accuracy: {val_accuracy:.4f}")
# Out:
# Epoch 1/100
# 1203/1203 [==============================] - 11s 4ms/step - loss: 0.6931 - accuracy: 0.5045 - val_loss: 0.6931 - val_accuracy: 0.5615
# Epoch 2/100
# 1203/1203 [==============================] - 7s 6ms/step - loss: 0.6930 - accuracy: 0.5273 - val_loss: 0.6929 - val_accuracy: 0.5586
# Epoch 3/100
# 1203/1203 [==============================] - 5s 4ms/step - loss: 0.6929 - accuracy: 0.5337 - val_loss: 0.6927 - val_accuracy: 0.5252
# Epoch 4/100
# 1203/1203 [==============================] - 6s 5ms/step - loss: 0.6926 - accuracy: 0.5466 - val_loss: 0.6924 - val_accuracy: 0.5667
# Epoch 5/100
# 1203/1203 [==============================] - 6s 5ms/step - loss: 0.6921 - accuracy: 0.5509 - val_loss: 0.6915 - val_accuracy: 0.5641
# Epoch 6/100
# 1203/1203 [==============================] - 5s 4ms/step - loss: 0.6908 - accuracy: 0.5468 - val_loss: 0.6900 - val_accuracy: 0.5402
# Epoch 7/100
# 1203/1203 [==============================] - 6s 5ms/step - loss: 0.6891 - accuracy: 0.5679 - val_loss: 0.6885 - val_accuracy: 0.5490
# Epoch 8/100
# 1203/1203 [==============================] - 5s 4ms/step - loss: 0.6874 - accuracy: 0.5753 - val_loss: 0.6867 - val_accuracy: 0.5764
# Epoch 9/100
#  319/1203 [======>.......................] - ETA: 3s - loss: 0.6857 - accuracy: 0.5813
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-cda5387c7992> in <cell line: 20>()
#      18 epochs = 100
#      19 batch_size = 32
# ---> 20 history = model2.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val))
#      21
#      22 # Evaluate the model2 on the validation set
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     924       # In this case we have created variables on the first call, so we run the
#     925       # defunned version which is guaranteed to never create variables.
# --> 926       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927     elif self._variable_creation_fn is not None:
#     928       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# Plot accuracy and loss vs. epoch
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Save the model with the highest validation accuracy to Google Drive
best_model_index = np.argmax(history.history['val_accuracy'])
best_model = model2
best_model.save('/content/drive/MyDrive/best_model.h5')
print(f"Best model saved with validation accuracy: {history.history['val_accuracy'][best_model_index]:.4f}")
# Out:
# Best model saved with validation accuracy: 0.8738
